# %%
import numpy as np

# %%
#1 Shape

# %%
arr=np.array([[5,6,7,8],[1,2,3,4]])
print(arr.shape)
# Out:
# (2, 4)

# %%
#ndim

# %%
print(arr.ndim)
# Out:
# 2

# %%
#size

# %%
print(arr.size)
# Out:
# 8

# %%
#itemsize output 8 for float64 array

# %%
print(arr.itemsize)
# Out:
# 8

# %%
#dtype

# %%
print(arr.dtype)
# Out:
# int64

# %%
#astype

# %%
arr_float=arr.astype(np.float64)
print(arr_float.dtype)
# Out:
# float64
