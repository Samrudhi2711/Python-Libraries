# %%
import pandas as pd

# %%
df=pd.read_csv("IPL_matches.csv")
df.sample(5)
# Out:
#       id  season        city        date                        team1  \
# 192  193    2010  Chandigarh  24-03-2010             Rajasthan Royals
# 401  402    2013        Pune  17-04-2013          Sunrisers Hyderabad
# 609  610    2016   Hyderabad  06-05-2016                Gujarat Lions
# 299  300    2011  Dharamsala  21-05-2011              Deccan Chargers
# 474  475    2014         NaN  28-04-2014  Royal Challengers Bangalore
#
#                    team2          toss_winner toss_decision  result  \
# 192      Kings XI Punjab      Kings XI Punjab         field  normal
# 401        Pune Warriors        Pune Warriors         field  normal
# 609  Sunrisers Hyderabad  Sunrisers Hyderabad         field  normal
# 299      Kings XI Punjab      Kings XI Punjab         field  normal
# 474      Kings XI Punjab      Kings XI Punjab         field  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %%
df.notnull().sum()
# Out:
# id                 636
# season             636
# city               629
# date               636
# team1              636
# team2              636
# toss_winner        636
# toss_decision      636
# result             636
# dl_applied         636
# winner             633
# win_by_runs        636
# win_by_wickets     636
# player_of_match    633
# venue              636
# umpire1            635
# umpire2            635
# umpire3              0
# dtype: int64

# %%
#df_clean=df.drop(columns=["umpire3"],inplace=True)
#df_clean.columns

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, team1, team2, toss_winner, toss_decision, result, dl_applied, winner, win_by_runs, win_by_wickets, player_of_match, venue, umpire1, umpire2]
# Index: []

# %%
df.shape
# Out:
# (0, 17)

# %%
df_cleaned = df.dropna(subset=["umpire3"])

# %%
df_cleaned.shape
# Out:
# (0, 18)

# %%
df.drop(columns=['umpire3'], inplace=False)
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1      2    2017       Pune  06-04-2017               Mumbai Indians
# 2      3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3      4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4      5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  22-05-2016             Delhi Daredevils
# 632  633    2016  Bangalore  24-05-2016                Gujarat Lions
# 633  634    2016      Delhi  25-05-2016          Sunrisers Hyderabad
# 634  635    2016      Delhi  27-05-2016                Gujarat Lions
# 635  636    2016  Bangalore  29-05-2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.drop(columns=['toss_decision', 'dl_applied'], inplace=False).shape
# Out:
# (636, 16)

# %%
df = df.drop('umpire3', axis=1)         # axis=1 means drop column
df = df.drop(['result', 'dl_applied'], axis=1)

# %%
df.shape
# Out:
# (636, 14)

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'winner', 'win_by_runs', 'win_by_wickets', 'player_of_match', 'venue',
#        'umpire1', 'umpire2'],
#       dtype='object')

# %%
df.shape
# Out:
# (636, 14)

# %%
df.isnull().sum()
# Out:
# id                 0
# season             0
# city               7
# date               0
# team1              0
# team2              0
# toss_winner        0
# winner             3
# win_by_runs        0
# win_by_wickets     0
# player_of_match    3
# venue              0
# umpire1            1
# umpire2            1
# dtype: int64

# %%
#fillna()

# %%
df_fillna=df.fillna(value={"city":"Pune","winner":"Royal Challengers Bangalore",'player_of_match':"B Kumar"})

# %%
df_fillna.isnull().sum()
# Out:
# id                 0
# season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            1
# umpire2            1
# dtype: int64

# %%
df_filled = df.fillna(method="ffill")
df_filled.isnull().sum()
# Out:
# /var/folders/zs/rgm7kj4s3bb8xy2q5rcm2pnh0000gn/T/ipykernel_3886/1002631712.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_filled = df.fillna(method="ffill")
# id                 0
# season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
df_filled = df.fillna(method="bfill")
df_filled.isnull().sum()
# Out:
# /var/folders/zs/rgm7kj4s3bb8xy2q5rcm2pnh0000gn/T/ipykernel_3886/4156521478.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_filled = df.fillna(method="bfill")
# id                 0
# season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'winner', 'win_by_runs', 'win_by_wickets', 'player_of_match', 'venue',
#        'umpire1', 'umpire2'],
#       dtype='object')

# %%
#df.rename(columns={old:new}) rename columns

# %%
df.rename(columns={'id':'Id'})
# Out:
#       Id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1      2    2017       Pune  06-04-2017               Mumbai Indians
# 2      3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3      4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4      5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  22-05-2016             Delhi Daredevils
# 632  633    2016  Bangalore  24-05-2016                Gujarat Lions
# 633  634    2016      Delhi  25-05-2016          Sunrisers Hyderabad
# 634  635    2016      Delhi  27-05-2016                Gujarat Lions
# 635  636    2016  Bangalore  29-05-2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore
# ...

# %%
#df.astype('int'):change datatype of column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   winner           633 non-null    object
#  8   win_by_runs      636 non-null    int64
#  9   win_by_wickets   636 non-null    int64
#  10  player_of_match  633 non-null    object
#  11  venue            636 non-null    object
#  12  umpire1          635 non-null    object
#  13  umpire2          635 non-null    object
# dtypes: int64(4), object(10)
# memory usage: 69.7+ KB

# %%
df['id'].astype(float).info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 636 entries, 0 to 635
# Series name: id
# Non-Null Count  Dtype
# --------------  -----
# 636 non-null    float64
# dtypes: float64(1)
# memory usage: 5.1 KB

# %%
df.drop_duplicates().shape
# Out:
# (636, 14)

# %%
#reset the index

# %%
#df.reset_index()
