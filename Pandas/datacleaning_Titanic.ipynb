# %%
import pandas as pd

# %%
df=pd.read_csv("titanic.csv")
df.head(5)
# Out:
#   Cabin            Ticket number  Survived
# 0   NaN         A/5 21171      5         0
# 1   C85          PC 17599      3         1
# 2   NaN  STON/O2. 3101282      6         1
# 3  C123            113803      3         1
# 4   NaN            373450      A         0

# %%
df.shape
# Out:
# (891, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Cabin     204 non-null    object
#  1   Ticket    891 non-null    object
#  2   number    891 non-null    object
#  3   Survived  891 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 28.0+ KB

# %%
df.describe()
# Out:
#          Survived
# count  891.000000
# mean     0.383838
# std      0.486592
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      1.000000

# %%
df.isnull().sum()
# Out:
# Cabin       687
# Ticket        0
# number        0
# Survived      0
# dtype: int64

# %%
#dropna lost many data so fillna()

# %%
df.dropna()
# Out:
#            Cabin    Ticket number  Survived
# 1            C85  PC 17599      3         1
# 3           C123    113803      3         1
# 6            E46     17463      2         0
# 10            G6   PP 9549      1         1
# 11          C103    113783      1         1
# ..           ...       ...    ...       ...
# 871          D35     11751      1         1
# 872  B51 B53 B55       695      6         0
# 879          C50     11767      A         1
# 887          B42    112053      3         1
# 889         C148    111369      2         1
#
# [204 rows x 4 columns]

# %%
df.shape
# Out:
# (891, 4)

# %%
df["Cabin"]=df["Cabin"].fillna("ccc")

# %%
df['Cabin']
# Out:
# 0      ccc
# 1      ccc
# 2      ccc
# 3      ccc
# 4      ccc
#       ...
# 886    ccc
# 887    ccc
# 888    ccc
# 889    ccc
# 890    ccc
# Name: Cabin, Length: 891, dtype: object

# %%
#method='ffill'
#df["Cabin"]=df["Cabin"].fillna(method='ffill') #old
#df["Cabin"]=df["Cabin"].bfill()

# %%
df['Cabin']
# Out:
# 0      ccc
# 1      ccc
# 2      ccc
# 3      ccc
# 4      ccc
#       ...
# 886    ccc
# 887    ccc
# 888    ccc
# 889    ccc
# 890    ccc
# Name: Cabin, Length: 891, dtype: object

# %%
df.isnull().sum()
# Out:
# Cabin       0
# Ticket      0
# number      0
# Survived    0
# dtype: int64

# %%
df['Cabin'].isnull().sum()
# Out:
# 0
