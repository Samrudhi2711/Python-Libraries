# %%
import pandas as pd

# %%
df=pd.read_csv("IPL_matches.csv")
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.tail()
# Out:
#       id  season       city        date                team1  \
# 631  632    2016     Raipur  22-05-2016     Delhi Daredevils
# 632  633    2016  Bangalore  24-05-2016        Gujarat Lions
# 633  634    2016      Delhi  25-05-2016  Sunrisers Hyderabad
# 634  635    2016      Delhi  27-05-2016        Gujarat Lions
# 635  636    2016  Bangalore  29-05-2016  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
df.sample(5)
# Out:
#       id  season        city        date                  team1  \
# 168  169    2009      Durban  20-05-2009    Chennai Super Kings
# 592  593    2016       Delhi  23-04-2016       Delhi Daredevils
# 47    48    2017  Chandigarh  09-05-2017        Kings XI Punjab
# 253  254    2011      Mumbai  20-04-2011          Pune Warriors
# 190  191    2010      Mumbai  22-03-2010  Kolkata Knight Riders
#
#                      team2            toss_winner toss_decision  result  \
# 168        Kings XI Punjab    Chennai Super Kings           bat  normal
# 592         Mumbai Indians         Mumbai Indians         field  normal
# 47   Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 253         Mumbai Indians          Pune Warriors           bat  normal
# 190         Mumbai Indians  Kolkata Knight Riders           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 168           0  Chennai Super Kings           24               0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
df.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
df.shape
# Out:
# (636, 18)

# %%
df.dtypes
# Out:
# id                   int64
# season               int64
# city                object
# date                object
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# result              object
# dl_applied           int64
# winner              object
# win_by_runs          int64
# win_by_wickets       int64
# player_of_match     object
# venue               object
# umpire1             object
# umpire2             object
# umpire3            float64
# dtype: object

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=636, step=1)

# %%
#select index data

# %%
#1)df['column']select a sing column

# %%
df['season'].sample(5)
# Out:
# 365    2012
# 456    2013
# 61     2008
# 192    2010
# 349    2012
# Name: season, dtype: int64

# %%
#df[['col1','col2']] select multiple column

# %%
df[["season","team1"]].sample(5)
# Out:
#      season                  team1
# 292    2011        Kings XI Punjab
# 388    2013       Rajasthan Royals
# 33     2017          Gujarat Lions
# 613    2016  Kolkata Knight Riders
# 63     2008        Deccan Chargers

# %%
#sd.iloc[0]:select the first row by position

# %%
df.iloc[0]
# Out:
# id                                                         1
# season                                                  2017
# city                                               Hyderabad
# date                                              05-04-2017
# team1                                    Sunrisers Hyderabad
# team2                            Royal Challengers Bangalore
# toss_winner                      Royal Challengers Bangalore
# toss_decision                                          field
# result                                                normal
# dl_applied                                                 0
# winner                                   Sunrisers Hyderabad
# win_by_runs                                               35
# win_by_wickets                                             0
# player_of_match                                 Yuvraj Singh
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %%
#df.loc[0]:select the first row by position

# %%
df.loc[0]
# Out:
# id                                                         1
# season                                                  2017
# city                                               Hyderabad
# date                                              05-04-2017
# team1                                    Sunrisers Hyderabad
# team2                            Royal Challengers Bangalore
# toss_winner                      Royal Challengers Bangalore
# toss_decision                                          field
# result                                                normal
# dl_applied                                                 0
# winner                                   Sunrisers Hyderabad
# win_by_runs                                               35
# win_by_wickets                                             0
# player_of_match                                 Yuvraj Singh
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %%
#select a spedcific element by position

# %%
df.iloc[0,7]
# Out:
# 'field'

# %%
#df.loc[0,'column'] select a specific element by label

# %%
df.loc[0,'venue']
# Out:
# 'Rajiv Gandhi International Stadium, Uppal'

# %%
#df[df['col']>5]: filter rows where  columns>5

# %%
df[df['season']>2015].sample(5)
# Out:
#       id  season        city        date                        team1  \
# 45    46    2017  Chandigarh  07-05-2017              Kings XI Punjab
# 21    22    2017      Indore  20-04-2017              Kings XI Punjab
# 19    20    2017      Rajkot  18-04-2017  Royal Challengers Bangalore
# 576  577    2016      Mumbai  09-04-2016               Mumbai Indians
# 5      6    2017   Hyderabad  09-04-2017                Gujarat Lions
#
#                        team2          toss_winner toss_decision  result  \
# 45             Gujarat Lions        Gujarat Lions         field  normal
# 21            Mumbai Indians       Mumbai Indians         field  normal
# 19             Gujarat Lions        Gujarat Lions         field  normal
# 576  Rising Pune Supergiants       Mumbai Indians           bat  normal
# 5        Sunrisers Hyderabad  Sunrisers Hyderabad         field  normal
#
#      dl_applied                       winner  win_by_runs  win_by_wickets  \
# ...

# %%
#df.iloc[):4,0:2] slice row and column

# %%
df.iloc[0:10,1:10]
# Out:
#    season       city        date                        team1  \
# 0    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1    2017       Pune  06-04-2017               Mumbai Indians
# 2    2017     Rajkot  07-04-2017                Gujarat Lions
# 3    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 5    2017  Hyderabad  09-04-2017                Gujarat Lions
# 6    2017     Mumbai  09-04-2017        Kolkata Knight Riders
# 7    2017     Indore  10-04-2017  Royal Challengers Bangalore
# 8    2017       Pune  11-04-2017             Delhi Daredevils
# 9    2017     Mumbai  12-04-2017          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
#df.set_index('column') set a column as the index

# %%
df.set_index('id')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/zs/rgm7kj4s3bb8xy2q5rcm2pnh0000gn/T/ipykernel_2703/1110277897.py in ?()
# ----> 1 df.set_index('id')
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['id'] are in the columns"

# %%
df.sample(3)
# Out:
#      season        city        date                        team1  \
# id
# 256    2011  Chandigarh  21-04-2011              Kings XI Punjab
# 148    2009   Centurion  07-05-2009  Royal Challengers Bangalore
# 210    2010      Nagpur  05-04-2010             Rajasthan Royals
#
#                 team2       toss_winner toss_decision  result  dl_applied  \
# id
# 256  Rajasthan Royals  Rajasthan Royals         field  normal           0
# 148  Rajasthan Royals  Rajasthan Royals         field  normal           0
# 210   Deccan Chargers  Rajasthan Royals           bat  normal           0
#
#                winner  win_by_runs  win_by_wickets player_of_match  \
# id
# 256   Kings XI Punjab           48               0        SE Marsh
# 148  Rajasthan Royals            0               7         A Singh
# 210  Rajasthan Royals            2               0        SK Warne
#
#                                             venue          umpire1  \
# id
# ...
